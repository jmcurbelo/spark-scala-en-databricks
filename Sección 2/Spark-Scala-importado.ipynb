// %% [markdown]
// # Notebook Scala-Spark importado

// %%
val name = "Jose"

println(s"Hola $name !!!")

// %% [markdown]
// # Obteniendo las configuraciones de la sesión de Spark

// %%
spark.conf.getAll.foreach(println)
